# %% [markdown]
# Villalon Pineda Luis Enrique

# %% [markdown]
# ## Ejercicio 1
#
# Considera la función:
#
# $$
# f(n) = 1^4 + 2^4 + \cdots + n^4,\qquad n\geq 1,\ n\in \mathbb{N}
# $$
#
# * Escribe una función para encontrar el valor de $f(n)$ para $n$ arbitraria, que regrese un error si $n$ se sale del dominio.
# * Demuestra por inducción que:
#
# $$
# f(n) = \frac{1}{30}n(n+1)(2n+1)(3n^2+3n-1)
# $$

# %%
def Fn(i):
  sum = 0
  for i in range(i):
    sum += (i+1)**4
  return sum

# %%
for i in range(10):
  print(f"n = {i}; Suma = {Fn(i)}")
# Out:
# n = 0; Suma = 0
# n = 1; Suma = 1
# n = 2; Suma = 17
# n = 3; Suma = 98
# n = 4; Suma = 354
# n = 5; Suma = 979
# n = 6; Suma = 2275
# n = 7; Suma = 4676
# n = 8; Suma = 8772
# n = 9; Suma = 15333

# %% [markdown]
# ![MD3.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ## Ejercicio 2
#
# Considera la función:
#
# $$
# f(n) = n^2-1, \qquad n\geq 1,\ n\in\mathbb{N}
# $$
#
# * Escribe una función para encontrar el valor de $f(n)$ para $n$ arbitraria, que regrese un error si $n$ se sale del dominio.
# * Utilizando tu función, encuentra para cuáles argumentos $n$, $f(n)$ es divisible por 8. Realiza una conjetura y demuéstrala por inducción.

# %%
def f(n):
    if not isinstance(n, int) or n < 1:
        raise ValueError("El valor de n debe ser un número natural mayor o igual a 1.")
    return n**2 - 1

# %%
def mod8():
    if f(n) % 8 == 0:
        return True
    else:
        return False

# %%
for n in range(1,20):
  print(f"n = {n}; Suma = {f(n)}; Es divisibles entre 8: {mod8()}")
# Out:
# n = 1; Suma = 0; Es divisibles entre 8: True
# n = 2; Suma = 3; Es divisibles entre 8: False
# n = 3; Suma = 8; Es divisibles entre 8: True
# n = 4; Suma = 15; Es divisibles entre 8: False
# n = 5; Suma = 24; Es divisibles entre 8: True
# n = 6; Suma = 35; Es divisibles entre 8: False
# n = 7; Suma = 48; Es divisibles entre 8: True
# n = 8; Suma = 63; Es divisibles entre 8: False
# n = 9; Suma = 80; Es divisibles entre 8: True
# n = 10; Suma = 99; Es divisibles entre 8: False
# n = 11; Suma = 120; Es divisibles entre 8: True
# n = 12; Suma = 143; Es divisibles entre 8: False
# n = 13; Suma = 168; Es divisibles entre 8: True
# n = 14; Suma = 195; Es divisibles entre 8: False
# n = 15; Suma = 224; Es divisibles entre 8: True
# n = 16; Suma = 255; Es divisibles entre 8: False
# n = 17; Suma = 288; Es divisibles entre 8: True
# n = 18; Suma = 323; Es divisibles entre 8: False
# n = 19; Suma = 360; Es divisibles entre 8: True

# %% [markdown]
# ![MD1.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ## Ejercicio 3
#
# Considera ahora la función:
#
# $$
# f(n) = n^4-1, \qquad n\geq 1,\ n\in\mathbb{N}
# $$
#
# Realiza los mismos pasos del ejercicio anterior, pero ahora buscando para cuáles $n$ sucede que $f(n)$ es divisible por 16.
#
# ¿Notas algún patrón?

# %%
def f(n):
    if not isinstance(n, int) or n < 1:
        raise ValueError("El valor de n debe ser un número natural mayor o igual a 1.")
    return n**4 - 1

# %%
def mod16():
    if f(n) % 16 == 0:
        return True
    else:
        return False

# %%
for n in range(1,20):
  print(f"n = {n}; Suma = {f(n)}; Es divisibles entre 16: {mod16()}")
# Out:
# n = 1; Suma = 0; Es divisibles entre 16: True
# n = 2; Suma = 15; Es divisibles entre 16: False
# n = 3; Suma = 80; Es divisibles entre 16: True
# n = 4; Suma = 255; Es divisibles entre 16: False
# n = 5; Suma = 624; Es divisibles entre 16: True
# n = 6; Suma = 1295; Es divisibles entre 16: False
# n = 7; Suma = 2400; Es divisibles entre 16: True
# n = 8; Suma = 4095; Es divisibles entre 16: False
# n = 9; Suma = 6560; Es divisibles entre 16: True
# n = 10; Suma = 9999; Es divisibles entre 16: False
# n = 11; Suma = 14640; Es divisibles entre 16: True
# n = 12; Suma = 20735; Es divisibles entre 16: False
# n = 13; Suma = 28560; Es divisibles entre 16: True
# n = 14; Suma = 38415; Es divisibles entre 16: False
# n = 15; Suma = 50624; Es divisibles entre 16: True
# n = 16; Suma = 65535; Es divisibles entre 16: False
# n = 17; Suma = 83520; Es divisibles entre 16: True
# n = 18; Suma = 104975; Es divisibles entre 16: False
# n = 19; Suma = 130320; Es divisibles entre 16: True

# %% [markdown]
# ![MD2.jpg](data:image/jpeg;base64,...)
